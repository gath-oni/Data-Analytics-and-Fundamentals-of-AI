# %% [markdown]
# ## **Data Importation, Cleaning and Wrangling**

# %% [markdown]
# ### **1. Data Importation**

# %%
#!pip install matplotlib
#!pip install seaborn

# %%
import pandas as pd              ## For data importation and handling data frames
import numpy as np               ## For numeric operations
import matplotlib.pyplot as plt  ## For data visualization
import seaborn as sn             ## For data visualization

### Filter warnings
import warnings
warnings.filterwarnings("ignore")

# %%
# Reading the dataset into Jupyter Notebook

df = pd.read_csv("GSSsubset1.csv")

# %% [markdown]
# ### **2. General Data Inspection**

# %%
# 1. Check column names

print(f" Columns: {df.columns.tolist()}")
# Out:
#  Columns: ['id', 'sex', 'degree', 'income', 'marital', 'age', 'height', 'weight', 'hrswrk']

# %%
# 2. Check the shape of the data (x,y) x = observations , y = columns

print(f"Shape: {df.shape}")
# Out:
# Shape: (3000, 9)

# %%
# 3. Check the variable types

df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 9 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   id       3000 non-null   int64
#  1   sex      3000 non-null   str
#  2   degree   2942 non-null   str
#  3   income   2767 non-null   float64
#  4   marital  2934 non-null   str
#  5   age      3000 non-null   int64
#  6   height   3000 non-null   float64
#  7   weight   2879 non-null   float64
#  8   hrswrk   2933 non-null   float64
# dtypes: float64(4), int64(2), str(3)
# memory usage: 211.1 KB

# %%
# 4. Check the first few observations

df.head(20)
# Out:
#     id     sex          degree     income        marital  age  height  weight  \
# 0    1    MALE     HIGH SCHOOL   26722.56  NEVER MARRIED   18    73.2    86.3
# 1    2    MALE             NaN   36544.91        MARRIED   35    69.9    95.3
# 2    3  FEMALE     HIGH SCHOOL   59587.14       DIVORCED   28    70.1    60.9
# 3    4  FEMALE        GRADUATE        NaN        MARRIED   43    61.9    76.0
# 4    5    MALE     HIGH SCHOOL   48899.47        MARRIED   48    65.8    58.9
# 5    6  FEMALE     HIGH SCHOOL   47790.38        MARRIED   43    60.7    68.4
# 6    7  FEMALE        BACHELOR  102903.23        MARRIED   42    66.5    66.7
# 7    8    MALE     HIGH SCHOOL   36707.09  NEVER MARRIED   52    65.9    76.8
# 8    9  FEMALE        BACHELOR   48404.51        MARRIED   35    66.8    94.6
# 9   10    MALE     HIGH SCHOOL   29044.70  NEVER MARRIED   18    69.3    85.2
# 10  11  FEMALE        GRADUATE  419380.86      SEPARATED   58    62.4    64.8
# ...

# %%
# 5. Check the last few observations

df.tail(20)
# Out:
#         id     sex          degree     income        marital  age  height  \
# 2980  2981    MALE     HIGH SCHOOL        NaN  NEVER MARRIED   47    60.7
# 2981  2982  FEMALE     HIGH SCHOOL   38239.11        MARRIED   43    66.7
# 2982  2983    MALE     HIGH SCHOOL   79377.52        MARRIED   43    69.5
# 2983  2984    MALE     HIGH SCHOOL   25025.96  NEVER MARRIED   41    67.0
# 2984  2985    MALE  LT HIGH SCHOOL   31093.78       DIVORCED   32    70.6
# 2985  2986  FEMALE        BACHELOR        NaN        MARRIED   37    63.6
# 2986  2987  FEMALE     HIGH SCHOOL   55287.09        MARRIED   52    63.7
# 2987  2988    MALE     HIGH SCHOOL   40474.19        MARRIED   33    70.1
# 2988  2989    MALE  LT HIGH SCHOOL   17978.77  NEVER MARRIED   18    70.0
# 2989  2990    MALE     HIGH SCHOOL   80625.90        MARRIED   63    67.8
# 2990  2991  FEMALE        BACHELOR   47934.48        MARRIED   42    64.6
# 2991  2992    MALE     HIGH SCHOOL        NaN        MARRIED   53    70.0
# ...

# %% [markdown]
# #### **General Descriptive Statistics**

# %%
df.describe()
# Out:
#                 id         income          age       height       weight  \
# count  3000.000000    2767.000000  3000.000000  3000.000000  2879.000000
# mean   1500.500000   63871.815790    42.078000    67.400500    76.389232
# std     866.169729   51634.075898    13.314316     3.641297    14.584233
# min       1.000000    3720.040000    18.000000    58.100000    45.000000
# 25%     750.750000   31989.025000    33.000000    64.600000    65.800000
# 50%    1500.500000   49586.540000    42.000000    67.200000    75.700000
# 75%    2250.250000   78986.595000    51.000000    70.100000    85.700000
# max    3000.000000  609741.180000    80.000000    78.600000   120.000000
#
#             hrswrk
# count  2933.000000
# mean     39.778043
# std      12.594723
# min       0.000000
# 25%      34.000000
# 50%      41.000000
# 75%      48.000000
# max      79.000000

# %%
# Remove the ID column from the summary
df.drop(columns = ["id"]).describe()
# Out:
#               income          age       height       weight       hrswrk
# count    2767.000000  3000.000000  3000.000000  2879.000000  2933.000000
# mean    63871.815790    42.078000    67.400500    76.389232    39.778043
# std     51634.075898    13.314316     3.641297    14.584233    12.594723
# min      3720.040000    18.000000    58.100000    45.000000     0.000000
# 25%     31989.025000    33.000000    64.600000    65.800000    34.000000
# 50%     49586.540000    42.000000    67.200000    75.700000    41.000000
# 75%     78986.595000    51.000000    70.100000    85.700000    48.000000
# max    609741.180000    80.000000    78.600000   120.000000    79.000000

# %% [markdown]
# #### **General Frequency Table**

# %%
print("="*100)
print("Gender Distribution in the General Social Survey")
print("="*100)

df["sex"].value_counts()     # use [] when referencing column
# Out:
# ...
# Gender Distribution in the General Social Survey
# ...
# sex
# FEMALE    1563
# MALE      1437
# Name: count, dtype: int64

# %%
print("="*100)
print("Education Qualification in the General Social Survey")
print("="*100)

df["degree"].value_counts()
# Out:
# ...
# Education Qualification in the General Social Survey
# ...
# degree
# HIGH SCHOOL       1094
# LT HIGH SCHOOL     583
# BACHELOR           566
# JUNIOR COLLEGE     465
# GRADUATE           234
# Name: count, dtype: int64

# %%
print("="*100)
print("Marital Status Distribution in the General Social Survey")
print("="*100)

df["marital"].value_counts()
# Out:
# ...
# Marital Status Distribution in the General Social Survey
# ...
# marital
# MARRIED          1518
# NEVER MARRIED     691
# DIVORCED          382
# WIDOWED           227
# SEPARATED         116
# Name: count, dtype: int64

# %% [markdown]
# ### **3. Data Cleaning**

# %% [markdown]
# #### **Handling Missing Values**

# %%
df.head(20)
# Out:
#     id     sex          degree     income        marital  age  height  weight  \
# 0    1    MALE     HIGH SCHOOL   26722.56  NEVER MARRIED   18    73.2    86.3
# 1    2    MALE             NaN   36544.91        MARRIED   35    69.9    95.3
# 2    3  FEMALE     HIGH SCHOOL   59587.14       DIVORCED   28    70.1    60.9
# 3    4  FEMALE        GRADUATE        NaN        MARRIED   43    61.9    76.0
# 4    5    MALE     HIGH SCHOOL   48899.47        MARRIED   48    65.8    58.9
# 5    6  FEMALE     HIGH SCHOOL   47790.38        MARRIED   43    60.7    68.4
# 6    7  FEMALE        BACHELOR  102903.23        MARRIED   42    66.5    66.7
# 7    8    MALE     HIGH SCHOOL   36707.09  NEVER MARRIED   52    65.9    76.8
# 8    9  FEMALE        BACHELOR   48404.51        MARRIED   35    66.8    94.6
# 9   10    MALE     HIGH SCHOOL   29044.70  NEVER MARRIED   18    69.3    85.2
# 10  11  FEMALE        GRADUATE  419380.86      SEPARATED   58    62.4    64.8
# ...

# %%
# Check the presence of missing values

print("="*100)
print("Checking the Presence of Missing Values in the General Social Survey")
print("="*100)

print(df.isna().sum())
# Out:
# ...
# Checking the Presence of Missing Values in the General Social Survey
# ...
# id           0
# sex          0
# degree      58
# income     233
# marital     66
# age          0
# height       0
# weight     121
# hrswrk      67
# dtype: int64

# %%
# check the percentage of missing values
print("="*100)
print("Checking the Percentage of Missing Values per Variable in the General Social Survey")
print("="*100)

Missing_values = df.isna().mean()
Missing_values
# Out:
# ...
# Checking the Percentage of Missing Values per Variable in the General Social Survey
# ...
# id         0.000000
# sex        0.000000
# degree     0.019333
# income     0.077667
# marital    0.022000
# age        0.000000
# height     0.000000
# weight     0.040333
# hrswrk     0.022333
# dtype: float64

# %% [markdown]
# ##### **Complete Cases Analysis(Row Deletion)**

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 9 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   id       3000 non-null   int64
#  1   sex      3000 non-null   str
#  2   degree   2942 non-null   str
#  3   income   2767 non-null   float64
#  4   marital  2934 non-null   str
#  5   age      3000 non-null   int64
#  6   height   3000 non-null   float64
#  7   weight   2879 non-null   float64
#  8   hrswrk   2933 non-null   float64
# dtypes: float64(4), int64(2), str(3)
# memory usage: 211.1 KB

# %%
df_drop_all = df.dropna()
print(df_drop_all.isna().sum())
# Out:
# id         0
# sex        0
# degree     0
# income     0
# marital    0
# age        0
# height     0
# weight     0
# hrswrk     0
# dtype: int64

# %%
df_drop_all.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 2503 entries, 0 to 2999
# Data columns (total 9 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   id       2503 non-null   int64
#  1   sex      2503 non-null   str
#  2   degree   2503 non-null   str
#  3   income   2503 non-null   float64
#  4   marital  2503 non-null   str
#  5   age      2503 non-null   int64
#  6   height   2503 non-null   float64
#  7   weight   2503 non-null   float64
#  8   hrswrk   2503 non-null   float64
# dtypes: float64(4), int64(2), str(3)
# memory usage: 195.5 KB

# %% [markdown]
# ##### **Mean-Imputation(for symmetric data)**

# %%
# Identify the numeric columns

df_mean = df.copy()
df_mean.head()
# Out:
#    id     sex       degree    income        marital  age  height  weight  \
# 0   1    MALE  HIGH SCHOOL  26722.56  NEVER MARRIED   18    73.2    86.3
# 1   2    MALE          NaN  36544.91        MARRIED   35    69.9    95.3
# 2   3  FEMALE  HIGH SCHOOL  59587.14       DIVORCED   28    70.1    60.9
# 3   4  FEMALE     GRADUATE       NaN        MARRIED   43    61.9    76.0
# 4   5    MALE  HIGH SCHOOL  48899.47        MARRIED   48    65.8    58.9
#
#    hrswrk
# 0    35.0
# 1    47.0
# 2    16.0
# 3    44.0
# 4    44.0

# %%
df_mean.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 9 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   id       3000 non-null   int64
#  1   sex      3000 non-null   str
#  2   degree   2942 non-null   str
#  3   income   2767 non-null   float64
#  4   marital  2934 non-null   str
#  5   age      3000 non-null   int64
#  6   height   3000 non-null   float64
#  7   weight   2879 non-null   float64
#  8   hrswrk   2933 non-null   float64
# dtypes: float64(4), int64(2), str(3)
# memory usage: 211.1 KB

# %%
numeric_cols = df.select_dtypes(include = "number").columns
df_mean[numeric_cols] = df_mean[numeric_cols].fillna(df_mean[numeric_cols].mean())

# %%
print(df.isna().sum())
# Out:
# id           0
# sex          0
# degree      58
# income     233
# marital     66
# age          0
# height       0
# weight     121
# hrswrk      67
# dtype: int64

# %%
print(df_mean.isna().sum())
# Out:
# id          0
# sex         0
# degree     58
# income      0
# marital    66
# age         0
# height      0
# weight      0
# hrswrk      0
# dtype: int64

# %% [markdown]
# ##### **Mean imputation for assymetric data**

# %%
df_median = df.copy()
df_median.head()
# Out:
#    id     sex       degree    income        marital  age  height  weight  \
# 0   1    MALE  HIGH SCHOOL  26722.56  NEVER MARRIED   18    73.2    86.3
# 1   2    MALE          NaN  36544.91        MARRIED   35    69.9    95.3
# 2   3  FEMALE  HIGH SCHOOL  59587.14       DIVORCED   28    70.1    60.9
# 3   4  FEMALE     GRADUATE       NaN        MARRIED   43    61.9    76.0
# 4   5    MALE  HIGH SCHOOL  48899.47        MARRIED   48    65.8    58.9
#
#    hrswrk
# 0    35.0
# 1    47.0
# 2    16.0
# 3    44.0
# 4    44.0

# %%
numeric_cols = df_median.select_dtypes(include = "number").columns
df_median[numeric_cols] = df_median[numeric_cols].fillna(df_median[numeric_cols].median())

# %%
print(df_median.isna().sum())
# Out:
# id          0
# sex         0
# degree     58
# income      0
# marital    66
# age         0
# height      0
# weight      0
# hrswrk      0
# dtype: int64

# %% [markdown]
# ##### **Mode Imputation**

# %%
df["degree"].value_counts()
# Out:
# degree
# HIGH SCHOOL       1094
# LT HIGH SCHOOL     583
# BACHELOR           566
# JUNIOR COLLEGE     465
# GRADUATE           234
# Name: count, dtype: int64

# %%
df["sex"].value_counts()
# Out:
# sex
# FEMALE    1563
# MALE      1437
# Name: count, dtype: int64

# %%
df["marital"].value_counts()
# Out:
# marital
# MARRIED          1518
# NEVER MARRIED     691
# DIVORCED          382
# WIDOWED           227
# SEPARATED         116
# Name: count, dtype: int64

# %%
cat_cols = df.select_dtypes(include = ["object", "category"]).columns  # object rep string
for col in cat_cols:                                                   # checks each column
    mode_val = df[col].mode()                                          # returning mode in a column
    if not mode_val.empty:                                             # prevent error if mode doesn't exist
        df[col]= df[col].fillna(mode_val[0])                           # fill NaN with mode

# %%
df.isna().sum()   # count number of missing values after imputation
# Out:
# id           0
# sex          0
# degree       0
# income     233
# marital      0
# age          0
# height       0
# weight     121
# hrswrk      67
# dtype: int64

# %%
df["degree"].value_counts()
# Out:
# degree
# HIGH SCHOOL       1152
# LT HIGH SCHOOL     583
# BACHELOR           566
# JUNIOR COLLEGE     465
# GRADUATE           234
# Name: count, dtype: int64

# %%
numeric_cols = df.select_dtypes(include = "number").columns          # selects columns with numeric data types and returns them
df[numeric_cols] = df[numeric_cols].fillna(df[numeric_cols].mean())  # calculates mean of each column and replaces Nan with mean

# %%
## Check presence of missing values

df.isna().sum()
# Out:
# id         0
# sex        0
# degree     0
# income     0
# marital    0
# age        0
# height     0
# weight     0
# hrswrk     0
# dtype: int64

# %%
# Check data structure
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 9 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   id       3000 non-null   int64
#  1   sex      3000 non-null   str
#  2   degree   3000 non-null   str
#  3   income   3000 non-null   float64
#  4   marital  3000 non-null   str
#  5   age      3000 non-null   int64
#  6   height   3000 non-null   float64
#  7   weight   3000 non-null   float64
#  8   hrswrk   3000 non-null   float64
# dtypes: float64(4), int64(2), str(3)
# memory usage: 211.1 KB

# %% [markdown]
# #### **Checking Duplicate Entries**

# %%
dup_rows = df.duplicated().sum()
print(dup_rows)
# Out:
# 0

# %%
# Dropping duplicate rows if they exist

clean_df = df.drop_duplicates()
clean_df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 9 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   id       3000 non-null   int64
#  1   sex      3000 non-null   str
#  2   degree   3000 non-null   str
#  3   income   3000 non-null   float64
#  4   marital  3000 non-null   str
#  5   age      3000 non-null   int64
#  6   height   3000 non-null   float64
#  7   weight   3000 non-null   float64
#  8   hrswrk   3000 non-null   float64
# dtypes: float64(4), int64(2), str(3)
# memory usage: 211.1 KB

# %% [markdown]
# ### **4. Handling Outliers**

# %% [markdown]
# ##### **Outliers are values that lie abnormally very low or very high (far off the trend)**

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 9 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   id       3000 non-null   int64
#  1   sex      3000 non-null   str
#  2   degree   3000 non-null   str
#  3   income   3000 non-null   float64
#  4   marital  3000 non-null   str
#  5   age      3000 non-null   int64
#  6   height   3000 non-null   float64
#  7   weight   3000 non-null   float64
#  8   hrswrk   3000 non-null   float64
# dtypes: float64(4), int64(2), str(3)
# memory usage: 211.1 KB

# %%
# Check the presence of outliers

numeric_cols = df.select_dtypes(include = ["float64","int64"]).columns
for col in numeric_cols:
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5*IQR
    upper_bound = Q3 + 1.5*IQR

    outliers = df[(df[col] < lower_bound) | (df[col] > upper_bound)]
    
    print(f"Columns '{col}': {len(outliers)} Outliers")
# Out:
# Columns 'id': 0 Outliers
# Columns 'income': 201 Outliers
# Columns 'age': 10 Outliers
# Columns 'height': 2 Outliers
# Columns 'weight': 32 Outliers
# Columns 'hrswrk': 155 Outliers

# %%
numeric_cols = ["income", "age", "height", "weight", "hrswrk"]
outlier_id = {}                                                #creating a dictionary
for col in numeric_cols:
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5*IQR
    upper_bound = Q3 + 1.5*IQR

    outliers = df[(df[col] < lower_bound) | (df[col] > upper_bound)]

    outlier_id[col] = outliers["id"].tolist()

    print(f"Columns '{col}' : {len(outliers)} outliers")         # printing out columns with outliers and their number
    print(outliers["id"].tolist())
    print("="*100)
# Out:
# Columns 'income' : 201 outliers
# ...

# %%
# cap outliers

numeric_cols = df.select_dtypes(include = ["float64","int64"]).columns
for col in numeric_cols:
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5*IQR
    upper_bound = Q3 + 1.5*IQR

    df[col] = np.where(df[col] < lower_bound, lower_bound, df[col])
    df[col] = np.where(df[col] > upper_bound, upper_bound, df[col])

# %%
numeric_cols = df.select_dtypes(include = ["float64","int64"]).columns
for col in numeric_cols:
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5*IQR
    upper_bound = Q3 + 1.5*IQR

    outliers = df[(df[col] < lower_bound) | (df[col] > upper_bound)]
    
    print(f"Columns '{col}': {len(outliers)} Outliers")
# Out:
# Columns 'id': 0 Outliers
# Columns 'income': 0 Outliers
# Columns 'age': 0 Outliers
# Columns 'height': 0 Outliers
# Columns 'weight': 0 Outliers
# Columns 'hrswrk': 0 Outliers

# %%
# Check data after cleaning
df.head(10)
# Out:
#      id     sex       degree        income        marital   age  height  \
# 0   1.0    MALE  HIGH SCHOOL   26722.56000  NEVER MARRIED  18.0    73.2
# 1   2.0    MALE  HIGH SCHOOL   36544.91000        MARRIED  35.0    69.9
# 2   3.0  FEMALE  HIGH SCHOOL   59587.14000       DIVORCED  28.0    70.1
# 3   4.0  FEMALE     GRADUATE   63871.81579        MARRIED  43.0    61.9
# 4   5.0    MALE  HIGH SCHOOL   48899.47000        MARRIED  48.0    65.8
# 5   6.0  FEMALE  HIGH SCHOOL   47790.38000        MARRIED  43.0    60.7
# 6   7.0  FEMALE     BACHELOR  102903.23000        MARRIED  42.0    66.5
# 7   8.0    MALE  HIGH SCHOOL   36707.09000  NEVER MARRIED  52.0    65.9
# 8   9.0  FEMALE     BACHELOR   48404.51000        MARRIED  35.0    66.8
# 9  10.0    MALE  HIGH SCHOOL   29044.70000  NEVER MARRIED  18.0    69.3
#
#    weight     hrswrk
# 0    86.3  35.000000
# 1    95.3  47.000000
# 2    60.9  16.000000
# 3    76.0  44.000000
# 4    58.9  44.000000
# 5    68.4  46.000000
# ...

# %% [markdown]
# #### **Save data as clean data set**

# %%
df.to_csv("Cleaned_gss_data.csv")
